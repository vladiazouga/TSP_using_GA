# %% [markdown]
# <a href="https://colab.research.google.com/github/vladiazouga/TSP_using_GA/blob/main/TSA_with_GPA_Vzouga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np
import pandas as pd

# Initial print statements explaining the purpose of the code.
print("Genetic Algorithm for Traveling Salesman Problem")
print("------------------------------------------------")
print("This code demonstrates a genetic algorithm to solve the Traveling Salesman Problem (TSP).")
print("The TSP involves finding the shortest possible route that visits a set of cities once and returns to the starting city.")
print("In this implementation:")
print("- A population of routes is evolved over generations.")
print("- The fitness of each route is determined by its total distance.")
print("- Routes with shorter distances are more fit and have a higher chance of being selected for reproduction.")
print("- Crossover and mutation operations are used to create new routes in each generation.")
print("- The algorithm continues until a stopping criterion is met.")
print("Let's optimize a route for visiting a set of randomly generated cities.")
print("\nOptimizing route...\n")

# Define a City class to represent cities with x and y coordinates.
class City:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def distance_to(self, other_city):
        distance_x = abs(self.x - other_city.x)
        distance_y = abs(self.y - other_city.y)
        return np.sqrt(distance_x**2 + distance_y**2)

    def __repr__(self):
        return f"({self.x},{self.y})"

# Define a Fitness class to calculate the fitness (inverse of distance) of a route.
class Fitness:
    def __init__(self, route):
        self.route = route
        self.distance = 0
        self.fitness = 0.0

    def calculate_route_distance(self):
        if self.distance == 0:
            path_distance = sum(self.route[i].distance_to(self.route[i + 1]) for i in range(len(self.route) - 1))
            path_distance += self.route[-1].distance_to(self.route[0])
            self.distance = path_distance
        return self.distance

    def calculate_fitness(self):
        if self.fitness == 0:
            self.fitness = 1 / self.calculate_route_distance()
        return self.fitness

# Function to create a random route by shuffling a list of cities.
def create_random_route(city_list):
    return random.sample(city_list, len(city_list))

# Function to initialize a population of random routes.
def initialize_population(population_size, city_list):
    return [create_random_route(city_list) for _ in range(population_size)]

# Function to rank routes in a population based on fitness.
def rank_routes(population):
    return sorted(enumerate(Fitness(route).calculate_fitness() for route in population), key=lambda x: x[1], reverse=True)

# Function to select the elite routes from the ranked population.
def select_elite(ranked_population, elite_size):
    selected_indexes = [index for index, _ in ranked_population[:elite_size]]
    return selected_indexes

# Function to create a mating pool from the selected elite routes.
def create_mating_pool(population, selected_indexes):
    return [population[index] for index in selected_indexes]

# Function to perform crossover (reproduction) between two parent routes.
def crossover(parent_one, parent_two):
    gene_a, gene_b = sorted(random.sample(range(len(parent_one)), 2))
    child_part_one = parent_one[gene_a:gene_b]
    child_part_two = [city for city in parent_two if city not in child_part_one]
    return child_part_one + child_part_two

# Function to breed a new population from the mating pool.
def breed_population(mating_pool, elite_size):
    elite = mating_pool[:elite_size]
    non_elite = mating_pool[elite_size:]
    children = [crossover(random.choice(elite), random.choice(elite)) for _ in range(len(non_elite))]
    return elite + children

# Function to perform mutation on a route with a given mutation rate.
def mutate_route(route, mutation_rate):
    for i in range(len(route)):
        if random.random() < mutation_rate:
            j = random.randint(0, len(route) - 1)
            route[i], route[j] = route[j], route[i]
    return route

# Function to perform mutation on a population.
def mutate_population(population, mutation_rate):
    return [mutate_route(route, mutation_rate) for route in population]

# Function to evolve the current generation to the next generation.
def evolve_to_next_generation(current_generation, elite_size, mutation_rate):
    ranked_population = rank_routes(current_generation)
    selected_indexes = select_elite(ranked_population, elite_size)
    mating_pool_result = create_mating_pool(current_generation, selected_indexes)
    children = breed_population(mating_pool_result, elite_size)
    next_generation = mutate_population(children, mutation_rate)
    return next_generation

# Main genetic algorithm function to find the optimized route.
def genetic_algorithm(city_list, population_size, elite_size, mutation_rate, generations):
    population = initialize_population(population_size, city_list)
    print(f"Initial solution: {1 / rank_routes(population)[0][1]}")

    previous_best = 1 / rank_routes(population)[0][1]
    run_ender = 0
    total_generations = 0

    for _ in range(generations):
        if run_ender >= 500:
            break
        total_generations += 1
        population = evolve_to_next_generation(population, elite_size, mutation_rate)
        current_best = 1 / rank_routes(population)[0][1]
        dif = abs(current_best - previous_best)
        if dif < 1e-20:
            run_ender += 1
        else:
            previous_best = current_best

        # Print the best distance in each generation.
        print(f"Generation {total_generations}: Best Distance = {1 / current_best}")

    print(f"Optimized solution: {1 / rank_routes(population)[0][1]}")
    print(f"Total generations: {total_generations}")
    best_route_index = rank_routes(population)[0][0]
    best_route = population[best_route_index]
    print(f"Best Route: {best_route}")
    return best_route

# Generate a list of random cities.
city_list = [City(x=int(random.random() * 200), y=int(random.random() * 200)) for _ in range(25)]

# Run the genetic algorithm with specified parameters.
genetic_algorithm(city_list, population_size=100, elite_size=20, mutation_rate=0.01, generations=500)
# Out:
# Genetic Algorithm for Traveling Salesman Problem
# ------------------------------------------------
# This code demonstrates a genetic algorithm to solve the Traveling Salesman Problem (TSP).
# The TSP involves finding the shortest possible route that visits a set of cities once and returns to the starting city.
# In this implementation:
# - A population of routes is evolved over generations.
# - The fitness of each route is determined by its total distance.
# - Routes with shorter distances are more fit and have a higher chance of being selected for reproduction.
# - Crossover and mutation operations are used to create new routes in each generation.
# - The algorithm continues until a stopping criterion is met.
# Let's optimize a route for visiting a set of randomly generated cities.
#
# Optimizing route...
#
# Initial solution: 2162.9247854849136
# Generation 1: Best Distance = 0.0004623369276226619
# Generation 2: Best Distance = 0.0004623369276226619
# Generation 3: Best Distance = 0.0005020957507951709
# Generation 4: Best Distance = 0.0005020957507951709
# Generation 5: Best Distance = 0.0005020957507951709
# Generation 6: Best Distance = 0.000495091630049035
# Generation 7: Best Distance = 0.000495091630049035
# Generation 8: Best Distance = 0.00045008851151301013
# Generation 9: Best Distance = 0.00045008851151301013
# Generation 10: Best Distance = 0.00045008851151301013
# Generation 11: Best Distance = 0.00044161219202811446
# Generation 12: Best Distance = 0.00044161219202811446
# Generation 13: Best Distance = 0.00043109996819162545
# Generation 14: Best Distance = 0.00043109996819162545
# Generation 15: Best Distance = 0.0004516325594552169
# Generation 16: Best Distance = 0.0004516325594552169
# Generation 17: Best Distance = 0.0004516325594552169
# Generation 18: Best Distance = 0.0004516325594552169
# Generation 19: Best Distance = 0.0004516325594552169
# Generation 20: Best Distance = 0.0004516325594552169
# Generation 21: Best Distance = 0.0004516325594552169
# Generation 22: Best Distance = 0.0004516325594552169
# Generation 23: Best Distance = 0.0004516325594552169
# Generation 24: Best Distance = 0.0004516325594552169
# Generation 25: Best Distance = 0.0004516325594552169
# Generation 26: Best Distance = 0.0004516325594552169
# Generation 27: Best Distance = 0.0004404044202425333
# Generation 28: Best Distance = 0.0004748022058111678
# Generation 29: Best Distance = 0.0004748022058111678
# Generation 30: Best Distance = 0.0004748022058111678
# Generation 31: Best Distance = 0.00047661058856621755
# Generation 32: Best Distance = 0.00046038055334186444
# Generation 33: Best Distance = 0.00046038055334186444
# Generation 34: Best Distance = 0.00046038055334186444
# Generation 35: Best Distance = 0.00046038055334186444
# Generation 36: Best Distance = 0.00046038055334186444
# Generation 37: Best Distance = 0.0004433849999557475
# Generation 38: Best Distance = 0.0004433849999557475
# Generation 39: Best Distance = 0.00043053515116387705
# Generation 40: Best Distance = 0.00043053515116387705
# Generation 41: Best Distance = 0.0004400725166896537
# Generation 42: Best Distance = 0.0004400725166896537
# Generation 43: Best Distance = 0.00044182273774947504
# Generation 44: Best Distance = 0.0004499429286228437
# Generation 45: Best Distance = 0.0004499429286228437
# Generation 46: Best Distance = 0.00045279182317920516
# Generation 47: Best Distance = 0.0004611631354811705
# Generation 48: Best Distance = 0.0004611631354811705
# Generation 49: Best Distance = 0.0004611631354811705
# Generation 50: Best Distance = 0.0004611631354811705
# Generation 51: Best Distance = 0.0004611631354811705
# Generation 52: Best Distance = 0.000431731650478096
# Generation 53: Best Distance = 0.000431731650478096
# Generation 54: Best Distance = 0.000431731650478096
# Generation 55: Best Distance = 0.0004125155065009445
# Generation 56: Best Distance = 0.00043039239018040685
# Generation 57: Best Distance = 0.00043039239018040685
# Generation 58: Best Distance = 0.00043039239018040685
# Generation 59: Best Distance = 0.00043039239018040685
# Generation 60: Best Distance = 0.00043039239018040685
# Generation 61: Best Distance = 0.00043039239018040685
# Generation 62: Best Distance = 0.0004316736624875065
# Generation 63: Best Distance = 0.0004316736624875065
# Generation 64: Best Distance = 0.0004316736624875065
# Generation 65: Best Distance = 0.0004316736624875065
# Generation 66: Best Distance = 0.0004316736624875065
# Generation 67: Best Distance = 0.0004257228339168292
# Generation 68: Best Distance = 0.0004257228339168292
# Generation 69: Best Distance = 0.0004257228339168292
# Generation 70: Best Distance = 0.0004257228339168292
# Generation 71: Best Distance = 0.0004257228339168292
# Generation 72: Best Distance = 0.0004361561970225946
# Generation 73: Best Distance = 0.000421182449136351
# Generation 74: Best Distance = 0.000421182449136351
# Generation 75: Best Distance = 0.000421182449136351
# Generation 76: Best Distance = 0.000421182449136351
# Generation 77: Best Distance = 0.000421182449136351
# Generation 78: Best Distance = 0.000421182449136351
# Generation 79: Best Distance = 0.000421182449136351
# Generation 80: Best Distance = 0.000421182449136351
# Generation 81: Best Distance = 0.0004362473529536373
# Generation 82: Best Distance = 0.0004362473529536373
# Generation 83: Best Distance = 0.0004362473529536373
# Generation 84: Best Distance = 0.0004362473529536373
# Generation 85: Best Distance = 0.0004362473529536373
# Generation 86: Best Distance = 0.0004362473529536373
# Generation 87: Best Distance = 0.0004362473529536373
# Generation 88: Best Distance = 0.0004362473529536373
# Generation 89: Best Distance = 0.0004362473529536373
# Generation 90: Best Distance = 0.0004300131332691893
# Generation 91: Best Distance = 0.0004300131332691893
# Generation 92: Best Distance = 0.00043227891457545624
# Generation 93: Best Distance = 0.00043227891457545624
# Generation 94: Best Distance = 0.00043227891457545624
# Generation 95: Best Distance = 0.0004559504624746551
# Generation 96: Best Distance = 0.0004559504624746551
# Generation 97: Best Distance = 0.0004559504624746551
# Generation 98: Best Distance = 0.00041826112017953815
# Generation 99: Best Distance = 0.00045311640970741994
# Generation 100: Best Distance = 0.00045311640970741994
# Generation 101: Best Distance = 0.00045430528399447763
# Generation 102: Best Distance = 0.00045430528399447763
# Generation 103: Best Distance = 0.00045430528399447763
# Generation 104: Best Distance = 0.00042802065900802695
# Generation 105: Best Distance = 0.00042802065900802695
# Generation 106: Best Distance = 0.0004809300216815707
# Generation 107: Best Distance = 0.0004809300216815707
# Generation 108: Best Distance = 0.0004809300216815707
# Generation 109: Best Distance = 0.0004809300216815707
# Generation 110: Best Distance = 0.0004809300216815707
# Generation 111: Best Distance = 0.0004809300216815707
# Generation 112: Best Distance = 0.0004809300216815707
# Generation 113: Best Distance = 0.0004809300216815707
# Generation 114: Best Distance = 0.0004809300216815707
# Generation 115: Best Distance = 0.0004809300216815707
# Generation 116: Best Distance = 0.0004809300216815707
# Generation 117: Best Distance = 0.0004809300216815707
# Generation 118: Best Distance = 0.0004809300216815707
# Generation 119: Best Distance = 0.0004809300216815707
# Generation 120: Best Distance = 0.0004809300216815707
# Generation 121: Best Distance = 0.0004809300216815707
# Generation 122: Best Distance = 0.0004809300216815707
# Generation 123: Best Distance = 0.0004809300216815707
# Generation 124: Best Distance = 0.0004434674202225651
# Generation 125: Best Distance = 0.0004434674202225651
# Generation 126: Best Distance = 0.00045585790359606234
# Generation 127: Best Distance = 0.00045585790359606234
# Generation 128: Best Distance = 0.0004734304160897548
# Generation 129: Best Distance = 0.0004734304160897548
# Generation 130: Best Distance = 0.0004734304160897548
# Generation 131: Best Distance = 0.00045585790359606234
# Generation 132: Best Distance = 0.00045585790359606234
# Generation 133: Best Distance = 0.00045585790359606234
# Generation 134: Best Distance = 0.00045585790359606234
# Generation 135: Best Distance = 0.00045585790359606234
# Generation 136: Best Distance = 0.000464453848694401
# Generation 137: Best Distance = 0.000464453848694401
# Generation 138: Best Distance = 0.000464453848694401
# Generation 139: Best Distance = 0.000464453848694401
# Generation 140: Best Distance = 0.000464453848694401
# Generation 141: Best Distance = 0.000464453848694401
# Generation 142: Best Distance = 0.0004650652678343201
# Generation 143: Best Distance = 0.0004650652678343201
# Generation 144: Best Distance = 0.0004650652678343201
# Generation 145: Best Distance = 0.0004650652678343201
# Generation 146: Best Distance = 0.0004650652678343201
# Generation 147: Best Distance = 0.0004650652678343201
# Generation 148: Best Distance = 0.00045703667467580797
# Generation 149: Best Distance = 0.0004819243969029231
# Generation 150: Best Distance = 0.0004819243969029231
# Generation 151: Best Distance = 0.00045703667467580797
# Generation 152: Best Distance = 0.00045703667467580797
# Generation 153: Best Distance = 0.0004527797344914505
# Generation 154: Best Distance = 0.0004527797344914505
# Generation 155: Best Distance = 0.000472146479642901
# Generation 156: Best Distance = 0.000472146479642901
# Generation 157: Best Distance = 0.000472146479642901
# Generation 158: Best Distance = 0.000472146479642901
# Generation 159: Best Distance = 0.000472146479642901
# Generation 160: Best Distance = 0.0004527797344914505
# Generation 161: Best Distance = 0.0004527797344914505
# Generation 162: Best Distance = 0.0004527797344914505
# Generation 163: Best Distance = 0.0004413210676859568
# Generation 164: Best Distance = 0.000520943123437331
# Generation 165: Best Distance = 0.000520943123437331
# Generation 166: Best Distance = 0.000520943123437331
# Generation 167: Best Distance = 0.000520943123437331
# Generation 168: Best Distance = 0.000520943123437331
# Generation 169: Best Distance = 0.000520943123437331
# Generation 170: Best Distance = 0.000520943123437331
# Generation 171: Best Distance = 0.0005169486340364655
# Generation 172: Best Distance = 0.0005169486340364655
# Generation 173: Best Distance = 0.00042310993076553167
# Generation 174: Best Distance = 0.00042310993076553167
# Generation 175: Best Distance = 0.00042254802141557056
# Generation 176: Best Distance = 0.00042495581458934024
# Generation 177: Best Distance = 0.00042495581458934024
# Generation 178: Best Distance = 0.00042495581458934024
# Generation 179: Best Distance = 0.00042495581458934024
# Generation 180: Best Distance = 0.0004229688294474674
# Generation 181: Best Distance = 0.0004229688294474674
# Generation 182: Best Distance = 0.00041641783325259933
# Generation 183: Best Distance = 0.00041641783325259933
# Generation 184: Best Distance = 0.00041641783325259933
# Generation 185: Best Distance = 0.0004330785221100424
# Generation 186: Best Distance = 0.00043820766689719006
# Generation 187: Best Distance = 0.00041949995461679885
# Generation 188: Best Distance = 0.00041949995461679885
# Generation 189: Best Distance = 0.00041949995461679885
# Generation 190: Best Distance = 0.00041949995461679885
# Generation 191: Best Distance = 0.00041949995461679885
# Generation 192: Best Distance = 0.0004580093560676517
# Generation 193: Best Distance = 0.0004580093560676517
# Generation 194: Best Distance = 0.00041949995461679885
# Generation 195: Best Distance = 0.00041949995461679885
# Generation 196: Best Distance = 0.00042026502856996135
# Generation 197: Best Distance = 0.00042026502856996135
# Generation 198: Best Distance = 0.00041552283290677056
# Generation 199: Best Distance = 0.00041552283290677056
# Generation 200: Best Distance = 0.00040605264403004
# Generation 201: Best Distance = 0.00041705339025478294
# Generation 202: Best Distance = 0.00041705339025478294
# Generation 203: Best Distance = 0.00041705339025478294
# Generation 204: Best Distance = 0.00041705339025478294
# Generation 205: Best Distance = 0.0004014359200400652
# Generation 206: Best Distance = 0.0003941756722774581
# Generation 207: Best Distance = 0.0003966672885336874
# Generation 208: Best Distance = 0.0004358044792763314
# Generation 209: Best Distance = 0.0004358044792763314
# Generation 210: Best Distance = 0.0004358044792763314
# Generation 211: Best Distance = 0.0004358044792763314
# Generation 212: Best Distance = 0.0004358044792763314
# Generation 213: Best Distance = 0.0004358044792763314
# Generation 214: Best Distance = 0.0004358044792763314
# Generation 215: Best Distance = 0.0004358044792763314
# Generation 216: Best Distance = 0.0004358044792763314
# Generation 217: Best Distance = 0.0004358044792763314
# Generation 218: Best Distance = 0.0004358044792763314
# Generation 219: Best Distance = 0.0004445309279199848
# Generation 220: Best Distance = 0.0004445309279199848
# Generation 221: Best Distance = 0.00043553107142315094
# Generation 222: Best Distance = 0.00043553107142315094
# Generation 223: Best Distance = 0.00043553107142315094
# Generation 224: Best Distance = 0.00043553107142315094
# Generation 225: Best Distance = 0.00043553107142315094
# Generation 226: Best Distance = 0.00043553107142315094
# Generation 227: Best Distance = 0.00043553107142315094
# Generation 228: Best Distance = 0.00043553107142315094
# Generation 229: Best Distance = 0.00043553107142315094
# Generation 230: Best Distance = 0.00043553107142315094
# Generation 231: Best Distance = 0.0004520753590319014
# Generation 232: Best Distance = 0.0004520753590319014
# Generation 233: Best Distance = 0.0004520753590319014
# Generation 234: Best Distance = 0.0004520753590319014
# Generation 235: Best Distance = 0.0004181356048065718
# Generation 236: Best Distance = 0.0004181356048065718
# Generation 237: Best Distance = 0.00043072301378993636
# Generation 238: Best Distance = 0.00044795065221499183
# Generation 239: Best Distance = 0.00042334636297329715
# Generation 240: Best Distance = 0.00042334636297329715
# Generation 241: Best Distance = 0.00042334636297329715
# Generation 242: Best Distance = 0.00042334636297329715
# Generation 243: Best Distance = 0.00042334636297329715
# Generation 244: Best Distance = 0.00042334636297329715
# Generation 245: Best Distance = 0.00042334636297329715
# Generation 246: Best Distance = 0.0004265706693609094
# Generation 247: Best Distance = 0.0004265706693609094
# Generation 248: Best Distance = 0.0004181356048065718
# Generation 249: Best Distance = 0.0004181356048065718
# Generation 250: Best Distance = 0.0004181356048065718
# Generation 251: Best Distance = 0.0004181356048065718
# Generation 252: Best Distance = 0.0004181356048065718
# Generation 253: Best Distance = 0.0004181356048065718
# Generation 254: Best Distance = 0.0004181356048065718
# Generation 255: Best Distance = 0.0004181356048065718
# Generation 256: Best Distance = 0.0004181356048065718
# Generation 257: Best Distance = 0.0004181356048065718
# Generation 258: Best Distance = 0.0004181356048065718
# Generation 259: Best Distance = 0.00042113606820788304
# Generation 260: Best Distance = 0.00042113606820788304
# Generation 261: Best Distance = 0.00042113606820788304
# Generation 262: Best Distance = 0.0004742434620683337
# Generation 263: Best Distance = 0.00045419016690978573
# Generation 264: Best Distance = 0.00045419016690978573
# Generation 265: Best Distance = 0.00045419016690978573
# Generation 266: Best Distance = 0.00045419016690978573
# Generation 267: Best Distance = 0.00045419016690978573
# Generation 268: Best Distance = 0.00045419016690978573
# Generation 269: Best Distance = 0.00045419016690978573
# Generation 270: Best Distance = 0.00044465529899981375
# Generation 271: Best Distance = 0.00044465529899981375
# Generation 272: Best Distance = 0.00044208672198133334
# Generation 273: Best Distance = 0.0004423034293862276
# Generation 274: Best Distance = 0.0004423034293862276
# Generation 275: Best Distance = 0.0004423034293862276
# Generation 276: Best Distance = 0.0004423034293862276
# Generation 277: Best Distance = 0.0004423034293862276
# Generation 278: Best Distance = 0.0004423034293862276
# Generation 279: Best Distance = 0.0004423034293862276
# Generation 280: Best Distance = 0.0004423034293862276
# Generation 281: Best Distance = 0.0004423034293862276
# Generation 282: Best Distance = 0.00044133091130159005
# Generation 283: Best Distance = 0.00044164931584802884
# Generation 284: Best Distance = 0.00044164931584802884
# Generation 285: Best Distance = 0.00044117048473965803
# Generation 286: Best Distance = 0.00044117048473965803
# Generation 287: Best Distance = 0.0004372828036139664
# Generation 288: Best Distance = 0.000457791094780816
# Generation 289: Best Distance = 0.000457791094780816
# Generation 290: Best Distance = 0.000457791094780816
# Generation 291: Best Distance = 0.000457791094780816
# Generation 292: Best Distance = 0.00046944041218955354
# Generation 293: Best Distance = 0.00048194952039580557
# Generation 294: Best Distance = 0.00048194952039580557
# Generation 295: Best Distance = 0.00048194952039580557
# Generation 296: Best Distance = 0.00048194952039580557
# Generation 297: Best Distance = 0.00046944041218955354
# Generation 298: Best Distance = 0.00046944041218955354
# Generation 299: Best Distance = 0.00046944041218955354
# Generation 300: Best Distance = 0.00046944041218955354
# Generation 301: Best Distance = 0.00046944041218955354
# Generation 302: Best Distance = 0.00046944041218955354
# Generation 303: Best Distance = 0.0004784154288854445
# Generation 304: Best Distance = 0.0004817919974947112
# Generation 305: Best Distance = 0.0004628331454999487
# Generation 306: Best Distance = 0.00044019861105035885
# Generation 307: Best Distance = 0.00044019861105035885
# Generation 308: Best Distance = 0.00044019861105035885
# Generation 309: Best Distance = 0.00044019861105035885
# Generation 310: Best Distance = 0.00044019861105035885
# Generation 311: Best Distance = 0.00044019861105035885
# Generation 312: Best Distance = 0.00044019861105035885
# Generation 313: Best Distance = 0.00044019861105035885
# Generation 314: Best Distance = 0.00044019861105035885
# Generation 315: Best Distance = 0.00044019861105035885
# Generation 316: Best Distance = 0.00044019861105035885
# Generation 317: Best Distance = 0.00044019861105035885
# Generation 318: Best Distance = 0.00044019861105035885
# Generation 319: Best Distance = 0.0004512450894018804
# Generation 320: Best Distance = 0.0004512450894018804
# Generation 321: Best Distance = 0.0004512450894018804
# Generation 322: Best Distance = 0.00043363528997215835
# Generation 323: Best Distance = 0.00043363528997215835
# Generation 324: Best Distance = 0.0004318947651441286
# Generation 325: Best Distance = 0.0004318947651441286
# Generation 326: Best Distance = 0.0004318947651441286
# Generation 327: Best Distance = 0.0004963913394996468
# Generation 328: Best Distance = 0.0004963913394996468
# Generation 329: Best Distance = 0.0004318947651441286
# Generation 330: Best Distance = 0.0004318947651441286
# Generation 331: Best Distance = 0.00043023658165313274
# Generation 332: Best Distance = 0.00043023658165313274
# Generation 333: Best Distance = 0.00043023658165313274
# Generation 334: Best Distance = 0.00043023658165313274
# Generation 335: Best Distance = 0.00043023658165313274
# Generation 336: Best Distance = 0.00043023658165313274
# Generation 337: Best Distance = 0.00043626793186807386
# Generation 338: Best Distance = 0.00042954806648376747
# Generation 339: Best Distance = 0.00042954806648376747
# Generation 340: Best Distance = 0.00042954806648376747
# Generation 341: Best Distance = 0.00042954806648376747
# Generation 342: Best Distance = 0.0004299886483444321
# Generation 343: Best Distance = 0.0004299886483444321
# Generation 344: Best Distance = 0.00044099855754455036
# Generation 345: Best Distance = 0.0004364301378160947
# Generation 346: Best Distance = 0.0004299886483444321
# Generation 347: Best Distance = 0.0004299886483444321
# Generation 348: Best Distance = 0.0004299886483444321
# Generation 349: Best Distance = 0.0004299886483444321
# Generation 350: Best Distance = 0.00044656514888225104
# Generation 351: Best Distance = 0.00044656514888225104
# Generation 352: Best Distance = 0.00044656514888225104
# Generation 353: Best Distance = 0.00044656514888225104
# Generation 354: Best Distance = 0.00044656514888225104
# Generation 355: Best Distance = 0.0004958626166418123
# Generation 356: Best Distance = 0.0004958626166418123
# Generation 357: Best Distance = 0.0004958626166418123
# Generation 358: Best Distance = 0.0004958626166418123
# Generation 359: Best Distance = 0.00045784514652570186
# Generation 360: Best Distance = 0.00045784514652570186
# Generation 361: Best Distance = 0.00045784514652570186
# Generation 362: Best Distance = 0.00045784514652570186
# Generation 363: Best Distance = 0.000465963088989536
# Generation 364: Best Distance = 0.000465963088989536
# Generation 365: Best Distance = 0.000465963088989536
# Generation 366: Best Distance = 0.000465963088989536
# Generation 367: Best Distance = 0.000465963088989536
# Generation 368: Best Distance = 0.000465963088989536
# Generation 369: Best Distance = 0.000465963088989536
# Generation 370: Best Distance = 0.000465963088989536
# Generation 371: Best Distance = 0.000465963088989536
# Generation 372: Best Distance = 0.000465963088989536
# Generation 373: Best Distance = 0.000465963088989536
# Generation 374: Best Distance = 0.000465963088989536
# Generation 375: Best Distance = 0.000465963088989536
# Generation 376: Best Distance = 0.00045831040541637644
# Generation 377: Best Distance = 0.00045831040541637644
# Generation 378: Best Distance = 0.00045831040541637644
# Generation 379: Best Distance = 0.00045831040541637644
# Generation 380: Best Distance = 0.00045831040541637644
# Generation 381: Best Distance = 0.00045831040541637644
# Generation 382: Best Distance = 0.00045831040541637644
# Generation 383: Best Distance = 0.00045831040541637644
# Generation 384: Best Distance = 0.00045831040541637644
# Generation 385: Best Distance = 0.0004598871521068188
# Generation 386: Best Distance = 0.0004598871521068188
# Generation 387: Best Distance = 0.00044732562353640403
# Generation 388: Best Distance = 0.00045474345810859345
# Generation 389: Best Distance = 0.00045474345810859345
# Generation 390: Best Distance = 0.00045474345810859345
# Generation 391: Best Distance = 0.0004419656436057949
# Generation 392: Best Distance = 0.0004419656436057949
# Generation 393: Best Distance = 0.0004419656436057949
# Generation 394: Best Distance = 0.0004419656436057949
# Generation 395: Best Distance = 0.0004253020184191578
# Generation 396: Best Distance = 0.0004259130563626442
# Generation 397: Best Distance = 0.0004259130563626442
# Generation 398: Best Distance = 0.0004259130563626442
# Generation 399: Best Distance = 0.0004253020184191578
# Generation 400: Best Distance = 0.0004253020184191578
# Generation 401: Best Distance = 0.00047837771892658834
# Generation 402: Best Distance = 0.00047837771892658834
# Generation 403: Best Distance = 0.00047837771892658834
# Generation 404: Best Distance = 0.00047837771892658834
# Generation 405: Best Distance = 0.00047837771892658834
# Generation 406: Best Distance = 0.00047837771892658834
# Generation 407: Best Distance = 0.0004221417095996452
# Generation 408: Best Distance = 0.0004116447118580379
# Generation 409: Best Distance = 0.0004116447118580379
# Generation 410: Best Distance = 0.00042267219706127937
# Generation 411: Best Distance = 0.000438327449908596
# Generation 412: Best Distance = 0.000438327449908596
# Generation 413: Best Distance = 0.000438327449908596
# Generation 414: Best Distance = 0.000438327449908596
# Generation 415: Best Distance = 0.000438327449908596
# Generation 416: Best Distance = 0.000438327449908596
# Generation 417: Best Distance = 0.00041026045425974025
# Generation 418: Best Distance = 0.00041026045425974025
# Generation 419: Best Distance = 0.00041026045425974025
# Generation 420: Best Distance = 0.00040984877922553683
# Generation 421: Best Distance = 0.00040984877922553683
# Generation 422: Best Distance = 0.00040984877922553683
# Generation 423: Best Distance = 0.00040984877922553683
# Generation 424: Best Distance = 0.00040984877922553683
# Generation 425: Best Distance = 0.00040984877922553683
# Generation 426: Best Distance = 0.00040984877922553683
# Generation 427: Best Distance = 0.00042121564873730304
# Generation 428: Best Distance = 0.00042121564873730304
# Generation 429: Best Distance = 0.00042121564873730304
# Generation 430: Best Distance = 0.00042121564873730304
# Generation 431: Best Distance = 0.00043102067098076477
# Generation 432: Best Distance = 0.00043102067098076477
# Generation 433: Best Distance = 0.00043102067098076477
# Generation 434: Best Distance = 0.0004299106668865433
# Generation 435: Best Distance = 0.00044673311303906806
# Generation 436: Best Distance = 0.00044673311303906806
# Generation 437: Best Distance = 0.00044673311303906806
# Generation 438: Best Distance = 0.00044673311303906806
# Generation 439: Best Distance = 0.00044673311303906806
# Generation 440: Best Distance = 0.00042407786851377053
# Generation 441: Best Distance = 0.0004318107710696913
# Generation 442: Best Distance = 0.0004318107710696913
# Generation 443: Best Distance = 0.0004318107710696913
# Generation 444: Best Distance = 0.00044816829430124357
# Generation 445: Best Distance = 0.00044816829430124357
# Generation 446: Best Distance = 0.00044816829430124357
# Generation 447: Best Distance = 0.00044816829430124357
# Generation 448: Best Distance = 0.0004432673355102152
# Generation 449: Best Distance = 0.0004432673355102152
# Generation 450: Best Distance = 0.00044282820820620427
# Generation 451: Best Distance = 0.00044282820820620427
# Generation 452: Best Distance = 0.00044203583424368755
# Generation 453: Best Distance = 0.00044203583424368755
# Generation 454: Best Distance = 0.00044203583424368755
# Generation 455: Best Distance = 0.00044203583424368755
# Generation 456: Best Distance = 0.00044951542310336977
# Generation 457: Best Distance = 0.00044951542310336977
# Generation 458: Best Distance = 0.00044951542310336977
# Generation 459: Best Distance = 0.00041913823758001317
# Generation 460: Best Distance = 0.00042285253349546296
# Generation 461: Best Distance = 0.00042285253349546296
# Generation 462: Best Distance = 0.0004273963700310023
# Generation 463: Best Distance = 0.0004273963700310023
# Generation 464: Best Distance = 0.0004273963700310023
# Generation 465: Best Distance = 0.0004273963700310023
# Generation 466: Best Distance = 0.0004273963700310023
# Generation 467: Best Distance = 0.0004273963700310023
# Generation 468: Best Distance = 0.00042040871598835854
# Generation 469: Best Distance = 0.00042040871598835854
# Generation 470: Best Distance = 0.0004206035667005052
# Generation 471: Best Distance = 0.0004206035667005052
# Generation 472: Best Distance = 0.0004206035667005052
# Generation 473: Best Distance = 0.0004206035667005052
# Generation 474: Best Distance = 0.0004337350852266027
# Generation 475: Best Distance = 0.0004337350852266027
# Generation 476: Best Distance = 0.0004337350852266027
# Generation 477: Best Distance = 0.0004337350852266027
# Generation 478: Best Distance = 0.0004337350852266027
# Generation 479: Best Distance = 0.0004337350852266027
# Generation 480: Best Distance = 0.0004337350852266027
# Generation 481: Best Distance = 0.0004337350852266027
# Generation 482: Best Distance = 0.0004337350852266027
# Generation 483: Best Distance = 0.0004159496209368243
# Generation 484: Best Distance = 0.0004159496209368243
# Generation 485: Best Distance = 0.00044013618469895095
# Generation 486: Best Distance = 0.00044013618469895095
# Generation 487: Best Distance = 0.00044013618469895095
# Generation 488: Best Distance = 0.00041495935703061174
# Generation 489: Best Distance = 0.00041495935703061174
# Generation 490: Best Distance = 0.00041495935703061174
# Generation 491: Best Distance = 0.00041495935703061174
# Generation 492: Best Distance = 0.00041495935703061174
# Generation 493: Best Distance = 0.00041495935703061174
# Generation 494: Best Distance = 0.00041495935703061174
# Generation 495: Best Distance = 0.00041495935703061174
# Generation 496: Best Distance = 0.00041567528843361326
# Generation 497: Best Distance = 0.00041567528843361326
# Generation 498: Best Distance = 0.00041106554664022333
# Generation 499: Best Distance = 0.00041106554664022333
# Generation 500: Best Distance = 0.00041106554664022333
# Optimized solution: 2432.702054875033
# Total generations: 500
# Best Route: [(169,162), (179,36), (163,56), (11,121), (32,49), (135,3), (9,152), (50,93), (192,132), (100,26), (15,7), (41,92), (166,110), (179,17), (132,148), (79,155), (99,26), (112,5), (139,32), (47,101), (28,32), (54,9), (69,73), (176,134), (85,166)]
# [(169,162),
#  (179,36),
#  (163,56),
#  (11,121),
#  (32,49),
#  (135,3),
#  (9,152),
#  (50,93),
#  (192,132),
#  (100,26),
#  (15,7),
#  (41,92),
#  (166,110),
#  (179,17),
#  (132,148),
#  (79,155),
#  (99,26),
#  (112,5),
#  (139,32),
#  (47,101),
#  (28,32),
#  (54,9),
#  (69,73),
#  (176,134),
#  (85,166)]
