# %%
import random
import numpy as np
import pandas as pd

# Initial print statements explaining the purpose of the code.
print("Genetic Algorithm for Traveling Salesman Problem")
print("------------------------------------------------")
print("This code demonstrates a genetic algorithm to solve the Traveling Salesman Problem (TSP).")
print("The TSP involves finding the shortest possible route that visits a set of cities once and returns to the starting city.")
print("In this implementation:")
print("- A population of routes is evolved over generations.")
print("- The fitness of each route is determined by its total distance.")
print("- Routes with shorter distances are more fit and have a higher chance of being selected for reproduction.")
print("- Crossover and mutation operations are used to create new routes in each generation.")
print("- The algorithm continues until a stopping criterion is met.")
print("Let's optimize a route for visiting a set of randomly generated cities.")
print("\nOptimizing route...\n")

# Define a City class to represent cities with x and y coordinates.
class City:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def distance_to(self, other_city):
        distance_x = abs(self.x - other_city.x)
        distance_y = abs(self.y - other_city.y)
        return np.sqrt(distance_x**2 + distance_y**2)

    def __repr__(self):
        return f"({self.x},{self.y})"

# Define a Fitness class to calculate the fitness (inverse of distance) of a route.
class Fitness:
    def __init__(self, route):
        self.route = route
        self.distance = 0
        self.fitness = 0.0

    def calculate_route_distance(self):
        if self.distance == 0:
            path_distance = sum(self.route[i].distance_to(self.route[i + 1]) for i in range(len(self.route) - 1))
            path_distance += self.route[-1].distance_to(self.route[0])
            self.distance = path_distance
        return self.distance

    def calculate_fitness(self):
        if self.fitness == 0:
            self.fitness = 1 / self.calculate_route_distance()
        return self.fitness

# Function to create a random route by shuffling a list of cities.
def create_random_route(city_list):
    return random.sample(city_list, len(city_list))

# Function to initialize a population of random routes.
def initialize_population(population_size, city_list):
    return [create_random_route(city_list) for _ in range(population_size)]

# Function to rank routes in a population based on fitness.
def rank_routes(population):
    return sorted(enumerate(Fitness(route).calculate_fitness() for route in population), key=lambda x: x[1], reverse=True)

# Function to select the elite routes from the ranked population.
def select_elite(ranked_population, elite_size):
    selected_indexes = [index for index, _ in ranked_population[:elite_size]]
    return selected_indexes

# Function to create a mating pool from the selected elite routes.
def create_mating_pool(population, selected_indexes):
    return [population[index] for index in selected_indexes]

# Function to perform crossover (reproduction) between two parent routes.
def crossover(parent_one, parent_two):
    gene_a, gene_b = sorted(random.sample(range(len(parent_one)), 2))
    child_part_one = parent_one[gene_a:gene_b]
    child_part_two = [city for city in parent_two if city not in child_part_one]
    return child_part_one + child_part_two

# Function to breed a new population from the mating pool.
def breed_population(mating_pool, elite_size):
    elite = mating_pool[:elite_size]
    non_elite = mating_pool[elite_size:]
    children = [crossover(random.choice(elite), random.choice(elite)) for _ in range(len(non_elite))]
    return elite + children

# Function to perform mutation on a route with a given mutation rate.
def mutate_route(route, mutation_rate):
    for i in range(len(route)):
        if random.random() < mutation_rate:
            j = random.randint(0, len(route) - 1)
            route[i], route[j] = route[j], route[i]
    return route

# Function to perform mutation on a population.
def mutate_population(population, mutation_rate):
    return [mutate_route(route, mutation_rate) for route in population]

# Function to evolve the current generation to the next generation.
def evolve_to_next_generation(current_generation, elite_size, mutation_rate):
    ranked_population = rank_routes(current_generation)
    selected_indexes = select_elite(ranked_population, elite_size)
    mating_pool_result = create_mating_pool(current_generation, selected_indexes)
    children = breed_population(mating_pool_result, elite_size)
    next_generation = mutate_population(children, mutation_rate)
    return next_generation

# Main genetic algorithm function to find the optimized route.
def genetic_algorithm(city_list, population_size, elite_size, mutation_rate, generations):
    population = initialize_population(population_size, city_list)
    print(f"Initial solution: {1 / rank_routes(population)[0][1]}")

    previous_best = 1 / rank_routes(population)[0][1]
    run_ender = 0
    total_generations = 0

    for _ in range(generations):
        if run_ender >= 500:
            break
        total_generations += 1
        population = evolve_to_next_generation(population, elite_size, mutation_rate)
        current_best = 1 / rank_routes(population)[0][1]
        dif = abs(current_best - previous_best)
        if dif < 1e-20:
            run_ender += 1
        else:
            previous_best = current_best

        # Print the best distance in each generation.
        print(f"Generation {total_generations}: Best Distance = {1 / current_best}")

    print(f"Optimized solution: {1 / rank_routes(population)[0][1]}")
    print(f"Total generations: {total_generations}")
    best_route_index = rank_routes(population)[0][0]
    best_route = population[best_route_index]
    print(f"Best Route: {best_route}")
    return best_route

# Generate a list of random cities.
city_list = [City(x=int(random.random() * 200), y=int(random.random() * 200)) for _ in range(25)]

# Run the genetic algorithm with specified parameters.
genetic_algorithm(city_list, population_size=100, elite_size=20, mutation_rate=0.01, generations=500)
# Out:
# Genetic Algorithm for Traveling Salesman Problem
# ------------------------------------------------
# This code demonstrates a genetic algorithm to solve the Traveling Salesman Problem (TSP).
# The TSP involves finding the shortest possible route that visits a set of cities once and returns to the starting city.
# In this implementation:
# - A population of routes is evolved over generations.
# - The fitness of each route is determined by its total distance.
# - Routes with shorter distances are more fit and have a higher chance of being selected for reproduction.
# - Crossover and mutation operations are used to create new routes in each generation.
# - The algorithm continues until a stopping criterion is met.
# Let's optimize a route for visiting a set of randomly generated cities.
#
# Optimizing route...
#
# Initial solution: 2103.07305247456
# Generation 1: Best Distance = 0.0005075359103930513
# Generation 2: Best Distance = 0.0005075359103930513
# Generation 3: Best Distance = 0.0005075359103930513
# Generation 4: Best Distance = 0.0005075359103930513
# Generation 5: Best Distance = 0.0005075359103930513
# Generation 6: Best Distance = 0.0005075359103930513
# Generation 7: Best Distance = 0.0005016913938150736
# Generation 8: Best Distance = 0.0005016913938150736
# Generation 9: Best Distance = 0.0005016913938150736
# Generation 10: Best Distance = 0.0005016913938150736
# Generation 11: Best Distance = 0.0005016913938150736
# Generation 12: Best Distance = 0.0005016913938150736
# Generation 13: Best Distance = 0.0005016913938150736
# Generation 14: Best Distance = 0.0005016913938150736
# Generation 15: Best Distance = 0.0005016913938150736
# Generation 16: Best Distance = 0.0005016913938150736
# Generation 17: Best Distance = 0.0005016913938150736
# Generation 18: Best Distance = 0.0004958350981856013
# Generation 19: Best Distance = 0.0004958350981856013
# Generation 20: Best Distance = 0.0004958350981856013
# Generation 21: Best Distance = 0.0004958350981856013
# Generation 22: Best Distance = 0.0004958350981856013
# Generation 23: Best Distance = 0.0004958350981856013
# Generation 24: Best Distance = 0.0004824653351426543
# Generation 25: Best Distance = 0.0004824653351426543
# Generation 26: Best Distance = 0.0004824653351426543
# Generation 27: Best Distance = 0.0004824653351426543
# Generation 28: Best Distance = 0.0004824653351426543
# Generation 29: Best Distance = 0.0004824653351426543
# Generation 30: Best Distance = 0.00047230360856876085
# Generation 31: Best Distance = 0.00047230360856876085
# Generation 32: Best Distance = 0.00047230360856876085
# Generation 33: Best Distance = 0.00047230360856876085
# Generation 34: Best Distance = 0.00047230360856876085
# Generation 35: Best Distance = 0.00047230360856876085
# Generation 36: Best Distance = 0.0004668845685250447
# Generation 37: Best Distance = 0.00046766429482238587
# Generation 38: Best Distance = 0.0004642486957662196
# Generation 39: Best Distance = 0.0004642486957662196
# Generation 40: Best Distance = 0.0004642486957662196
# Generation 41: Best Distance = 0.0004642486957662196
# Generation 42: Best Distance = 0.00046231876466695874
# Generation 43: Best Distance = 0.00046231876466695874
# Generation 44: Best Distance = 0.00046231876466695874
# Generation 45: Best Distance = 0.00046231876466695874
# Generation 46: Best Distance = 0.00046231876466695874
# Generation 47: Best Distance = 0.00045189128627627114
# Generation 48: Best Distance = 0.00045189128627627114
# Generation 49: Best Distance = 0.00045189128627627114
# Generation 50: Best Distance = 0.00045189128627627114
# Generation 51: Best Distance = 0.00045189128627627114
# Generation 52: Best Distance = 0.00045189128627627114
# Generation 53: Best Distance = 0.0005083986013217354
# Generation 54: Best Distance = 0.0005083986013217354
# Generation 55: Best Distance = 0.0005083986013217354
# Generation 56: Best Distance = 0.0005083986013217354
# Generation 57: Best Distance = 0.0004571867781462097
# Generation 58: Best Distance = 0.0004571867781462097
# Generation 59: Best Distance = 0.0004567463801190299
# Generation 60: Best Distance = 0.0004567463801190299
# Generation 61: Best Distance = 0.0004567463801190299
# Generation 62: Best Distance = 0.0004567463801190299
# Generation 63: Best Distance = 0.0004567463801190299
# Generation 64: Best Distance = 0.0004567463801190299
# Generation 65: Best Distance = 0.0004613431568344565
# Generation 66: Best Distance = 0.0004613431568344565
# Generation 67: Best Distance = 0.00046898748702643706
# Generation 68: Best Distance = 0.0004831019733419794
# Generation 69: Best Distance = 0.0004831019733419794
# Generation 70: Best Distance = 0.0004831019733419794
# Generation 71: Best Distance = 0.0004831019733419794
# Generation 72: Best Distance = 0.0004831019733419794
# Generation 73: Best Distance = 0.0004831019733419794
# Generation 74: Best Distance = 0.0004831019733419794
# Generation 75: Best Distance = 0.0004831019733419794
# Generation 76: Best Distance = 0.0004831019733419794
# Generation 77: Best Distance = 0.0004831019733419794
# Generation 78: Best Distance = 0.0004626807758032841
# Generation 79: Best Distance = 0.0004626807758032841
# Generation 80: Best Distance = 0.0004626807758032841
# Generation 81: Best Distance = 0.0004626807758032841
# Generation 82: Best Distance = 0.0004626807758032841
# Generation 83: Best Distance = 0.00046764629797771477
# Generation 84: Best Distance = 0.0004887309027289523
# Generation 85: Best Distance = 0.0005059887608231407
# Generation 86: Best Distance = 0.0004696714014352119
# Generation 87: Best Distance = 0.0004696714014352119
# Generation 88: Best Distance = 0.0004696714014352119
# Generation 89: Best Distance = 0.0004696714014352119
# Generation 90: Best Distance = 0.00045925774495733505
# Generation 91: Best Distance = 0.0004879953027309102
# Generation 92: Best Distance = 0.0004879953027309102
# Generation 93: Best Distance = 0.0004879953027309102
# Generation 94: Best Distance = 0.0004879953027309102
# Generation 95: Best Distance = 0.0004879953027309102
# Generation 96: Best Distance = 0.0004879953027309102
# Generation 97: Best Distance = 0.0004879953027309102
# Generation 98: Best Distance = 0.0004879953027309102
# Generation 99: Best Distance = 0.0004879953027309102
# Generation 100: Best Distance = 0.0004879953027309102
# Generation 101: Best Distance = 0.0004879953027309102
# Generation 102: Best Distance = 0.0004879953027309102
# Generation 103: Best Distance = 0.0004879953027309102
# Generation 104: Best Distance = 0.0004879953027309102
# Generation 105: Best Distance = 0.00045243214688664494
# Generation 106: Best Distance = 0.00045243214688664494
# Generation 107: Best Distance = 0.00045243214688664494
# Generation 108: Best Distance = 0.00045243214688664494
# Generation 109: Best Distance = 0.00045243214688664494
# Generation 110: Best Distance = 0.00045243214688664494
# Generation 111: Best Distance = 0.0004498804432848182
# Generation 112: Best Distance = 0.0004498804432848182
# Generation 113: Best Distance = 0.0004498804432848182
# Generation 114: Best Distance = 0.0004498804432848182
# Generation 115: Best Distance = 0.0004498804432848182
# Generation 116: Best Distance = 0.0004386808777287401
# Generation 117: Best Distance = 0.0004386808777287401
# Generation 118: Best Distance = 0.00041618820915531905
# Generation 119: Best Distance = 0.0004220657968975307
# Generation 120: Best Distance = 0.0004220657968975307
# Generation 121: Best Distance = 0.00041618820915531905
# Generation 122: Best Distance = 0.0004433860921160979
# Generation 123: Best Distance = 0.0004253257758996793
# Generation 124: Best Distance = 0.000423509769176983
# Generation 125: Best Distance = 0.000423509769176983
# Generation 126: Best Distance = 0.000423509769176983
# Generation 127: Best Distance = 0.000423509769176983
# Generation 128: Best Distance = 0.000423509769176983
# Generation 129: Best Distance = 0.000423509769176983
# Generation 130: Best Distance = 0.00045247468936767375
# Generation 131: Best Distance = 0.0004499925728934303
# Generation 132: Best Distance = 0.0004499925728934303
# Generation 133: Best Distance = 0.0004499925728934303
# Generation 134: Best Distance = 0.0004499925728934303
# Generation 135: Best Distance = 0.0004499925728934303
# Generation 136: Best Distance = 0.0004558788071024538
# Generation 137: Best Distance = 0.0004558788071024538
# Generation 138: Best Distance = 0.0004558788071024538
# Generation 139: Best Distance = 0.0004558788071024538
# Generation 140: Best Distance = 0.0004558788071024538
# Generation 141: Best Distance = 0.0004558788071024538
# Generation 142: Best Distance = 0.0004558788071024538
# Generation 143: Best Distance = 0.0004565016302140489
# Generation 144: Best Distance = 0.0004565016302140489
# Generation 145: Best Distance = 0.0004565016302140489
# Generation 146: Best Distance = 0.0004565016302140489
# Generation 147: Best Distance = 0.0004565016302140489
# Generation 148: Best Distance = 0.0004565016302140489
# Generation 149: Best Distance = 0.0004565016302140489
# Generation 150: Best Distance = 0.00047497641600033726
# Generation 151: Best Distance = 0.00047497641600033726
# Generation 152: Best Distance = 0.00047497641600033726
# Generation 153: Best Distance = 0.00045306396568627733
# Generation 154: Best Distance = 0.00045306396568627733
# Generation 155: Best Distance = 0.00048502228569317565
# Generation 156: Best Distance = 0.00048502228569317565
# Generation 157: Best Distance = 0.00048502228569317565
# Generation 158: Best Distance = 0.00048502228569317565
# Generation 159: Best Distance = 0.00048502228569317565
# Generation 160: Best Distance = 0.00048502228569317565
# Generation 161: Best Distance = 0.00048502228569317565
# Generation 162: Best Distance = 0.00047189704457747164
# Generation 163: Best Distance = 0.0004653891709110379
# Generation 164: Best Distance = 0.00046912416436718524
# Generation 165: Best Distance = 0.00046912416436718524
# Generation 166: Best Distance = 0.00046912416436718524
# Generation 167: Best Distance = 0.0004653891709110379
# Generation 168: Best Distance = 0.0004600423271005079
# Generation 169: Best Distance = 0.0004600423271005079
# Generation 170: Best Distance = 0.0004600423271005079
# Generation 171: Best Distance = 0.0004600423271005079
# Generation 172: Best Distance = 0.0004600423271005079
# Generation 173: Best Distance = 0.0004690325759095527
# Generation 174: Best Distance = 0.0004600423271005079
# Generation 175: Best Distance = 0.0004600423271005079
# Generation 176: Best Distance = 0.0004580679457495115
# Generation 177: Best Distance = 0.0004580679457495115
# Generation 178: Best Distance = 0.0004580679457495115
# Generation 179: Best Distance = 0.0004580679457495115
# Generation 180: Best Distance = 0.0004580679457495115
# Generation 181: Best Distance = 0.0004580679457495115
# Generation 182: Best Distance = 0.0004580679457495115
# Generation 183: Best Distance = 0.0004580679457495115
# Generation 184: Best Distance = 0.0004580679457495115
# Generation 185: Best Distance = 0.000471006995618804
# Generation 186: Best Distance = 0.000471006995618804
# Generation 187: Best Distance = 0.000471006995618804
# Generation 188: Best Distance = 0.000471006995618804
# Generation 189: Best Distance = 0.000471006995618804
# Generation 190: Best Distance = 0.000471006995618804
# Generation 191: Best Distance = 0.0004550474545712125
# Generation 192: Best Distance = 0.0004550474545712125
# Generation 193: Best Distance = 0.0004550474545712125
# Generation 194: Best Distance = 0.0004550474545712125
# Generation 195: Best Distance = 0.0004550474545712125
# Generation 196: Best Distance = 0.0004550474545712125
# Generation 197: Best Distance = 0.0004550474545712125
# Generation 198: Best Distance = 0.0004550474545712125
# Generation 199: Best Distance = 0.0004550474545712125
# Generation 200: Best Distance = 0.0004550474545712125
# Generation 201: Best Distance = 0.0004598179799922023
# Generation 202: Best Distance = 0.00045504899490253465
# Generation 203: Best Distance = 0.00045504899490253465
# Generation 204: Best Distance = 0.00045504899490253465
# Generation 205: Best Distance = 0.00047964112195296346
# Generation 206: Best Distance = 0.00047964112195296346
# Generation 207: Best Distance = 0.0004627104831840684
# Generation 208: Best Distance = 0.0004627104831840684
# Generation 209: Best Distance = 0.0004627104831840684
# Generation 210: Best Distance = 0.0004939060656726387
# Generation 211: Best Distance = 0.0004939060656726387
# Generation 212: Best Distance = 0.0004939060656726387
# Generation 213: Best Distance = 0.0004939060656726387
# Generation 214: Best Distance = 0.0004939060656726387
# Generation 215: Best Distance = 0.0004939060656726387
# Generation 216: Best Distance = 0.0004939060656726387
# Generation 217: Best Distance = 0.0004939060656726387
# Generation 218: Best Distance = 0.0004939060656726387
# Generation 219: Best Distance = 0.0004765697288142844
# Generation 220: Best Distance = 0.0004765697288142844
# Generation 221: Best Distance = 0.0004765697288142844
# Generation 222: Best Distance = 0.0004765697288142844
# Generation 223: Best Distance = 0.0004765697288142844
# Generation 224: Best Distance = 0.0004765697288142844
# Generation 225: Best Distance = 0.0004765697288142844
# Generation 226: Best Distance = 0.0004765697288142844
# Generation 227: Best Distance = 0.00045384833579123143
# Generation 228: Best Distance = 0.00045384833579123143
# Generation 229: Best Distance = 0.00045384833579123143
# Generation 230: Best Distance = 0.00045384833579123143
# Generation 231: Best Distance = 0.00045384833579123143
# Generation 232: Best Distance = 0.00045384833579123143
# Generation 233: Best Distance = 0.00044945103762926376
# Generation 234: Best Distance = 0.00044945103762926376
# Generation 235: Best Distance = 0.0004442248614284002
# Generation 236: Best Distance = 0.0004442248614284002
# Generation 237: Best Distance = 0.0004442248614284002
# Generation 238: Best Distance = 0.0004442248614284002
# Generation 239: Best Distance = 0.0004442248614284002
# Generation 240: Best Distance = 0.0004442248614284002
# Generation 241: Best Distance = 0.00045293563192957514
# Generation 242: Best Distance = 0.00045293563192957514
# Generation 243: Best Distance = 0.00045293563192957514
# Generation 244: Best Distance = 0.00045293563192957514
# Generation 245: Best Distance = 0.0004382439943544666
# Generation 246: Best Distance = 0.0004382439943544666
# Generation 247: Best Distance = 0.0004382439943544666
# Generation 248: Best Distance = 0.0004382439943544666
# Generation 249: Best Distance = 0.0004474033240983479
# Generation 250: Best Distance = 0.0004474033240983479
# Generation 251: Best Distance = 0.0004381389583293328
# Generation 252: Best Distance = 0.0004381389583293328
# Generation 253: Best Distance = 0.0004308895384170966
# Generation 254: Best Distance = 0.0004308895384170966
# Generation 255: Best Distance = 0.0004308895384170966
# Generation 256: Best Distance = 0.0004208665121988695
# Generation 257: Best Distance = 0.0004208665121988695
# Generation 258: Best Distance = 0.0004208665121988695
# Generation 259: Best Distance = 0.00041597147764524606
# Generation 260: Best Distance = 0.00041597147764524606
# Generation 261: Best Distance = 0.0004309576343744087
# Generation 262: Best Distance = 0.0004622484670191759
# Generation 263: Best Distance = 0.0004622484670191759
# Generation 264: Best Distance = 0.0004622484670191759
# Generation 265: Best Distance = 0.0004622484670191759
# Generation 266: Best Distance = 0.0004622484670191759
# Generation 267: Best Distance = 0.0004622484670191759
# Generation 268: Best Distance = 0.0004622484670191759
# Generation 269: Best Distance = 0.0004622484670191759
# Generation 270: Best Distance = 0.0004622484670191759
# Generation 271: Best Distance = 0.0004622484670191759
# Generation 272: Best Distance = 0.0004622484670191759
# Generation 273: Best Distance = 0.0004622484670191759
# Generation 274: Best Distance = 0.0004622484670191759
# Generation 275: Best Distance = 0.0004622484670191759
# Generation 276: Best Distance = 0.0004622484670191759
# Generation 277: Best Distance = 0.0004622484670191759
# Generation 278: Best Distance = 0.0004622484670191759
# Generation 279: Best Distance = 0.0004622484670191759
# Generation 280: Best Distance = 0.0004622484670191759
# Generation 281: Best Distance = 0.0004622484670191759
# Generation 282: Best Distance = 0.0004622484670191759
# Generation 283: Best Distance = 0.0004622484670191759
# Generation 284: Best Distance = 0.0004622484670191759
# Generation 285: Best Distance = 0.0004622484670191759
# Generation 286: Best Distance = 0.0004622484670191759
# Generation 287: Best Distance = 0.0004622484670191759
# Generation 288: Best Distance = 0.0004622484670191759
# Generation 289: Best Distance = 0.0004622484670191759
# Generation 290: Best Distance = 0.0004622484670191759
# Generation 291: Best Distance = 0.0004622484670191759
# Generation 292: Best Distance = 0.0004622484670191759
# Generation 293: Best Distance = 0.0004622484670191759
# Generation 294: Best Distance = 0.0004622484670191759
# Generation 295: Best Distance = 0.0004622484670191759
# Generation 296: Best Distance = 0.0004622484670191759
# Generation 297: Best Distance = 0.00046851373234611045
# Generation 298: Best Distance = 0.00046851373234611045
# Generation 299: Best Distance = 0.00046851373234611045
# Generation 300: Best Distance = 0.00046851373234611045
# Generation 301: Best Distance = 0.00046851373234611045
# Generation 302: Best Distance = 0.00046851373234611045
# Generation 303: Best Distance = 0.00046851373234611045
# Generation 304: Best Distance = 0.00046851373234611045
# Generation 305: Best Distance = 0.00046851373234611045
# Generation 306: Best Distance = 0.00046851373234611045
# Generation 307: Best Distance = 0.00046851373234611045
# Generation 308: Best Distance = 0.00046851373234611045
# Generation 309: Best Distance = 0.00046851373234611045
# Generation 310: Best Distance = 0.00046851373234611045
# Generation 311: Best Distance = 0.00046851373234611045
# Generation 312: Best Distance = 0.00046851373234611045
# Generation 313: Best Distance = 0.00046851373234611045
# Generation 314: Best Distance = 0.00046851373234611045
# Generation 315: Best Distance = 0.00045544807267287445
# Generation 316: Best Distance = 0.00045544807267287445
# Generation 317: Best Distance = 0.00045544807267287445
# Generation 318: Best Distance = 0.00045544807267287445
# Generation 319: Best Distance = 0.00045544807267287445
# Generation 320: Best Distance = 0.00045544807267287445
# Generation 321: Best Distance = 0.00045544807267287445
# Generation 322: Best Distance = 0.00045544807267287445
# Generation 323: Best Distance = 0.00045544807267287445
# Generation 324: Best Distance = 0.00045544807267287445
# Generation 325: Best Distance = 0.00045544807267287445
# Generation 326: Best Distance = 0.00045544807267287445
# Generation 327: Best Distance = 0.00045544807267287445
# Generation 328: Best Distance = 0.0004718218529547522
# Generation 329: Best Distance = 0.0004718218529547522
# Generation 330: Best Distance = 0.0004718218529547522
# Generation 331: Best Distance = 0.0004798799348340267
# Generation 332: Best Distance = 0.0004798799348340267
# Generation 333: Best Distance = 0.0005664283200461539
# Generation 334: Best Distance = 0.000482834469328174
# Generation 335: Best Distance = 0.000482834469328174
# Generation 336: Best Distance = 0.000482834469328174
# Generation 337: Best Distance = 0.000482834469328174
# Generation 338: Best Distance = 0.00048204355731739257
# Generation 339: Best Distance = 0.00048204355731739257
# Generation 340: Best Distance = 0.0004633720012444425
# Generation 341: Best Distance = 0.0004943472187187715
# Generation 342: Best Distance = 0.0005006735269297031
# Generation 343: Best Distance = 0.0004943472187187715
# Generation 344: Best Distance = 0.0004943472187187715
# Generation 345: Best Distance = 0.0004943472187187715
# Generation 346: Best Distance = 0.0004943472187187715
# Generation 347: Best Distance = 0.0004943472187187715
# Generation 348: Best Distance = 0.0004943472187187715
# Generation 349: Best Distance = 0.0004943472187187715
# Generation 350: Best Distance = 0.0004943472187187715
# Generation 351: Best Distance = 0.0004943472187187715
# Generation 352: Best Distance = 0.0004943472187187715
# Generation 353: Best Distance = 0.0004943472187187715
# Generation 354: Best Distance = 0.0004943472187187715
# Generation 355: Best Distance = 0.0005006735269297031
# Generation 356: Best Distance = 0.0005491298269940285
# Generation 357: Best Distance = 0.0005491298269940285
# Generation 358: Best Distance = 0.0005491298269940285
# Generation 359: Best Distance = 0.0005491298269940285
# Generation 360: Best Distance = 0.0005491298269940285
# Generation 361: Best Distance = 0.0005491298269940285
# Generation 362: Best Distance = 0.0005491298269940285
# Generation 363: Best Distance = 0.0005491298269940285
# Generation 364: Best Distance = 0.0005426991701935307
# Generation 365: Best Distance = 0.0005426991701935307
# Generation 366: Best Distance = 0.0005426991701935307
# Generation 367: Best Distance = 0.0005426991701935307
# Generation 368: Best Distance = 0.000536501358560649
# Generation 369: Best Distance = 0.0005241055132491106
# Generation 370: Best Distance = 0.0005241055132491106
# Generation 371: Best Distance = 0.0004807414750618874
# Generation 372: Best Distance = 0.0004807414750618874
# Generation 373: Best Distance = 0.0004807414750618874
# Generation 374: Best Distance = 0.0004807414750618874
# Generation 375: Best Distance = 0.0004807414750618874
# Generation 376: Best Distance = 0.0004807414750618874
# Generation 377: Best Distance = 0.0004807414750618874
# Generation 378: Best Distance = 0.0004807414750618874
# Generation 379: Best Distance = 0.0004807414750618874
# Generation 380: Best Distance = 0.0004807414750618874
# Generation 381: Best Distance = 0.0004807414750618874
# Generation 382: Best Distance = 0.00047749549675661217
# Generation 383: Best Distance = 0.00047749549675661217
# Generation 384: Best Distance = 0.00047749549675661217
# Generation 385: Best Distance = 0.00047749549675661217
# Generation 386: Best Distance = 0.00047749549675661217
# Generation 387: Best Distance = 0.0004911157229273602
# Generation 388: Best Distance = 0.0004911157229273602
# Generation 389: Best Distance = 0.0004911157229273602
# Generation 390: Best Distance = 0.0004911157229273602
# Generation 391: Best Distance = 0.00045183771677485677
# Generation 392: Best Distance = 0.00045183771677485677
# Generation 393: Best Distance = 0.00045183771677485677
# Generation 394: Best Distance = 0.00044840796275721516
# Generation 395: Best Distance = 0.00044840796275721516
# Generation 396: Best Distance = 0.00044840796275721516
# Generation 397: Best Distance = 0.00044840796275721516
# Generation 398: Best Distance = 0.00044840796275721516
# Generation 399: Best Distance = 0.00044840796275721516
# Generation 400: Best Distance = 0.00044840796275721516
# Generation 401: Best Distance = 0.00042116282551750786
# Generation 402: Best Distance = 0.00042116282551750786
# Generation 403: Best Distance = 0.0004183568000924685
# Generation 404: Best Distance = 0.0004183568000924685
# Generation 405: Best Distance = 0.0004183568000924685
# Generation 406: Best Distance = 0.00043230528736040534
# Generation 407: Best Distance = 0.00043230528736040534
# Generation 408: Best Distance = 0.00043230528736040534
# Generation 409: Best Distance = 0.00043230528736040534
# Generation 410: Best Distance = 0.00043230528736040534
# Generation 411: Best Distance = 0.00043230528736040534
# Generation 412: Best Distance = 0.0004362378690651683
# Generation 413: Best Distance = 0.0004362378690651683
# Generation 414: Best Distance = 0.0004362378690651683
# Generation 415: Best Distance = 0.0004362378690651683
# Generation 416: Best Distance = 0.0004362378690651683
# Generation 417: Best Distance = 0.00042714810816735606
# Generation 418: Best Distance = 0.0004164143867447019
# Generation 419: Best Distance = 0.00040894815613802375
# Generation 420: Best Distance = 0.00040894815613802375
# Generation 421: Best Distance = 0.0004117165132690999
# Generation 422: Best Distance = 0.0004117165132690999
# Generation 423: Best Distance = 0.0004117165132690999
# Generation 424: Best Distance = 0.0004271754523344096
# Generation 425: Best Distance = 0.0004271754523344096
# Generation 426: Best Distance = 0.0004271754523344096
# Generation 427: Best Distance = 0.0004271754523344096
# Generation 428: Best Distance = 0.0004271754523344096
# Generation 429: Best Distance = 0.0004271754523344096
# Generation 430: Best Distance = 0.0004271754523344096
# Generation 431: Best Distance = 0.0004271754523344096
# Generation 432: Best Distance = 0.00043617083985829846
# Generation 433: Best Distance = 0.00043617083985829846
# Generation 434: Best Distance = 0.0005041625745161487
# Generation 435: Best Distance = 0.0005117552515726931
# Generation 436: Best Distance = 0.0005117552515726931
# Generation 437: Best Distance = 0.0005117552515726931
# Generation 438: Best Distance = 0.0005117552515726931
# Generation 439: Best Distance = 0.0005117552515726931
# Generation 440: Best Distance = 0.0005117552515726931
# Generation 441: Best Distance = 0.0005117552515726931
# Generation 442: Best Distance = 0.0005117552515726931
# Generation 443: Best Distance = 0.0005117552515726931
# Generation 444: Best Distance = 0.0005117552515726931
# Generation 445: Best Distance = 0.0005117552515726931
# Generation 446: Best Distance = 0.0005117552515726931
# Generation 447: Best Distance = 0.0004855164719783452
# Generation 448: Best Distance = 0.0004855164719783452
# Generation 449: Best Distance = 0.0005118678154579385
# Generation 450: Best Distance = 0.0005118678154579385
# Generation 451: Best Distance = 0.0005118678154579385
# Generation 452: Best Distance = 0.0005118678154579385
# Generation 453: Best Distance = 0.00047350054363614583
# Generation 454: Best Distance = 0.00047350054363614583
# Generation 455: Best Distance = 0.0005018222098245347
# Generation 456: Best Distance = 0.0005018222098245347
# Generation 457: Best Distance = 0.0005018222098245347
# Generation 458: Best Distance = 0.0005018222098245347
# Generation 459: Best Distance = 0.0005018222098245347
# Generation 460: Best Distance = 0.0005018222098245347
# Generation 461: Best Distance = 0.0004533701480559822
# Generation 462: Best Distance = 0.00044296637685810255
# Generation 463: Best Distance = 0.00046439222935125126
# Generation 464: Best Distance = 0.00046439222935125126
# Generation 465: Best Distance = 0.00046439222935125126
# Generation 466: Best Distance = 0.00046439222935125126
# Generation 467: Best Distance = 0.00046439222935125126
# Generation 468: Best Distance = 0.00046439222935125126
# Generation 469: Best Distance = 0.00046439222935125126
# Generation 470: Best Distance = 0.00046439222935125126
# Generation 471: Best Distance = 0.00045163855171909275
# Generation 472: Best Distance = 0.0004418370186440128
# Generation 473: Best Distance = 0.0004418370186440128
# Generation 474: Best Distance = 0.0004418370186440128
# Generation 475: Best Distance = 0.00042747626422137735
# Generation 476: Best Distance = 0.00042747626422137735
# Generation 477: Best Distance = 0.00042747626422137735
# Generation 478: Best Distance = 0.00042526135591449267
# Generation 479: Best Distance = 0.00042526135591449267
# Generation 480: Best Distance = 0.00042526135591449267
# Generation 481: Best Distance = 0.00042526135591449267
# Generation 482: Best Distance = 0.00042526135591449267
# Generation 483: Best Distance = 0.00044258724090313705
# Generation 484: Best Distance = 0.00044258724090313705
# Generation 485: Best Distance = 0.00044258724090313705
# Generation 486: Best Distance = 0.00044258724090313705
# Generation 487: Best Distance = 0.00044258724090313705
# Generation 488: Best Distance = 0.00044258724090313705
# Generation 489: Best Distance = 0.00044258724090313705
# Generation 490: Best Distance = 0.00044258724090313705
# Generation 491: Best Distance = 0.00044258724090313705
# Generation 492: Best Distance = 0.00045489803393908475
# Generation 493: Best Distance = 0.0004683357290569573
# Generation 494: Best Distance = 0.0004683357290569573
# Generation 495: Best Distance = 0.0004683357290569573
# Generation 496: Best Distance = 0.0004928565588972396
# Generation 497: Best Distance = 0.0004928565588972396
# Generation 498: Best Distance = 0.0004928565588972396
# Generation 499: Best Distance = 0.0004928565588972396
# Generation 500: Best Distance = 0.0004928565588972396
# Optimized solution: 2028.9879112849537
# Total generations: 500
# Best Route: [(50,93), (91,120), (109,163), (99,163), (58,188), (192,98), (35,139), (143,102), (176,127), (35,182), (44,128), (12,154), (38,24), (145,9), (175,27), (122,50), (160,153), (177,158), (111,47), (140,63), (197,114), (91,23), (95,197), (81,153), (40,137)]
# [(50,93),
#  (91,120),
#  (109,163),
#  (99,163),
#  (58,188),
#  (192,98),
#  (35,139),
#  (143,102),
#  (176,127),
#  (35,182),
#  (44,128),
#  (12,154),
#  (38,24),
#  (145,9),
#  (175,27),
#  (122,50),
#  (160,153),
#  (177,158),
#  (111,47),
#  (140,63),
#  (197,114),
#  (91,23),
#  (95,197),
#  (81,153),
#  (40,137)]
